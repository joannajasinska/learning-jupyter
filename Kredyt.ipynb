# %%
class Rynek:
    cenaZaM2=0
    wzrost = 0
    
    def wycenaMieszkania(self, mieszkanie):
        return self.cenaZaM2 * mieszkanie.powierzchnia
    
    def wycenMieszkaniePoLatach(self, mieszkanie, lata):
        wsp = pow((1+self.wzrost),lata)
        return self.wycenaMieszkania(mieszkanie)*wsp
    
    
class Mieszkanie:
    powierzchnia = 0

# %%
rynekWarszawa = Rynek()
rynekWarszawa.cenaZaM2 = 12500
rynekWarszawa.wzrost = 0.05

mieszkanieOgrodowa = Mieszkanie()
mieszkanieOgrodowa.powierzchnia = 60

cena = rynekWarszawa.wycenaMieszkania(mieszkanieOgrodowa)
print ("cena="+str(cena))
# Out:
# cena=750000

# %%
cenaPo5Latach = rynekWarszawa.wycenMieszkaniePoLatach(mieszkanieOgrodowa,5)
print("Cena po 5 latach: " +str(cenaPo5Latach))
# Out:
# Cena po 5 latach: 957211.1718750002

# %%
mieszkanieAnielewicza = Mieszkanie()
mieszkanieAnielewicza.powierzchnia = 56

cena2 = rynekWarszawa.wycenaMieszkania(mieszkanieAnielewicza)
cenaPo5Latach2 = rynekWarszawa.wycenMieszkaniePoLatach(mieszkanieAnielewicza,5)

# %%
print("Ceny mieszkania na Ogrodowej przez 5 kolejnych lat:")
for x in range (1,6):
    cenaPoXLatach = rynekWarszawa.wycenMieszkaniePoLatach(mieszkanieOgrodowa,x) 
    print(cenaPoXLatach)
# Out:
# Ceny mieszkania na Ogrodowej przez 5 kolejnych lat:
# 787500.0
# 826875.0
# 868218.7500000001
# 911629.6875000001
# 957211.1718750002

# %%
print("Ceny mieszkania na Anielewicza przez 5 kolejnych lat:")
for x in range (1,6):
    cenaPoXLatach = rynekWarszawa.wycenMieszkaniePoLatach(mieszkanieAnielewicza,x) 
    print(cenaPoXLatach)
# Out:
# Ceny mieszkania na Anielewicza przez 5 kolejnych lat:
# 735000.0
# 771750.0
# 810337.5000000001
# 850854.3750000001
# 893397.0937500002

# %%
# %matplotlib notebook
from matplotlib import pyplot

# %%
lata= range(0,6)
cenaOgrodowa= [0]*6
for x in lata:
    cenaOgrodowa[x]= rynekWarszawa.wycenMieszkaniePoLatach(mieszkanieOgrodowa,x)
print(cenaOgrodowa)
pyplot.plot(lata, cenaOgrodowa, 'o', color='black')
# Out:
# [750000.0, 787500.0, 826875.0, 868218.7500000001, 911629.6875000001, 957211.1718750002]
# <img src="data:image/png;base64,..." width="640">

# %%
#import matplotlib.pyplot as plt
#plt.style.use('seaborn-whitegrid')
#import numpy as np

# %%
#x = np.linspace(0, 10, 30)
#y = np.sin(x)
#plt.plot(x, y, 'o', color='black');

# %%
lata= range(0,6)
cenaAnielewicza= [0]*6
for x in lata:
    cenaAnielewicza[x]= rynekWarszawa.wycenMieszkaniePoLatach(mieszkanieAnielewicza,x)
print(cenaAnielewicza)
pyplot.plot(lata, cenaAnielewicza, 's', color='blue')
# Out:
# [700000.0, 735000.0, 771750.0, 810337.5000000001, 850854.3750000001, 893397.0937500002]
